# %% [markdown]
# ANÁLISE DE DADOS UTILIZANDO PYTHON
#
# 1º EATAPA - DADOS
#
# Será realizada a análise de dados referente a Educação Superior no Brasil, para isso, foram utilizadas base de dados disponibilizadas pelo Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira Legislação e Documentos - INEP.
#
# Diante da diversidade que há no Brasil e da atual discusão referente a inclusão social e a adoção de politicas públicas em prol das minorias. Esta análise visa identificar o quantitativo de alunos indigenas e com deficiência que concluíram um curso superior do ano de 2017 no Brasil. Bem como a relação desse quantitativo com o quantitativo global da população indigena e da população de pessoas com deficiência.
#
# Foram utilizados os dados diponíveis no link: http://portal.inep.gov.br/microdados, opção Censo da Educação superior, do ano de 2017.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
plt.style.use('ggplot')

#Extraindo as bases ano 2017

#Ano 2017

data_curso = pd.read_csv("Desktop\Dados\curso.csv", sep="|", dtype=object, encoding="ANSI")
Diretorio= r"Desktop\Dados\aluno.csv"
data_aluno = pd.read_csv(Diretorio, sep="|", dtype=object, encoding="ANSI")

# %% [markdown]
# 2º ETAPA - TRATAMENTO DOS DADOS
#
# 2.1 LIMPEZA E PREPARAÇÃO DOS DADOS
#
# Nesta etapa foram tratados:
# - Os dados foram manipulados realizando a junção e combinação entre tabelas.
# - Os dados ausentes.
# - Foram identificados os dados ausentes e substituídos por dados.

# %%
# Criando Data Frames
aluno = pd.DataFrame(data_aluno, columns=['CO_CURSO','CO_IES','CO_ALUNO_CURSO','TP_DEFICIENCIA','IN_DEFICIENCIA_AUDITIVA',
                                          'IN_DEFICIENCIA_FISICA','IN_DEFICIENCIA_INTELECTUAL','IN_DEFICIENCIA_MULTIPLA',
                                          'IN_DEFICIENCIA_SURDEZ','IN_DEFICIENCIA_SURDOCEGUEIRA','IN_DEFICIENCIA_BAIXA_VISAO',
                                          'IN_DEFICIENCIA_CEGUEIRA','IN_DEFICIENCIA_SUPERDOTACAO','IN_TGD_AUTISMO_INFANTIL',
                                          'IN_TGD_TRANSTOR_DESINTEGRATIVO','TP_SITUACAO','TP_COR_RACA','CO_UF_NASCIMENTO'])


curso = pd.DataFrame(data_curso, columns=['CO_CURSO', 'CO_IES' ,'NO_CURSO'])

# Concatenando os data frames

#aluno_curso = pd.concat([aluno, curso], axis=0, join='inner')
aluno_curso = pd.merge(aluno, curso, on=['CO_CURSO','CO_IES'], how='inner')
aluno_curso.info()
# Renomeando colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11589194 entries, 0 to 11589193
# Data columns (total 19 columns):
# CO_CURSO                          object
# CO_IES                            object
# CO_ALUNO_CURSO                    object
# TP_DEFICIENCIA                    object
# IN_DEFICIENCIA_AUDITIVA           object
# IN_DEFICIENCIA_FISICA             object
# IN_DEFICIENCIA_INTELECTUAL        object
# IN_DEFICIENCIA_MULTIPLA           object
# IN_DEFICIENCIA_SURDEZ             object
# IN_DEFICIENCIA_SURDOCEGUEIRA      object
# IN_DEFICIENCIA_BAIXA_VISAO        object
# IN_DEFICIENCIA_CEGUEIRA           object
# IN_DEFICIENCIA_SUPERDOTACAO       object
# IN_TGD_AUTISMO_INFANTIL           object
# IN_TGD_TRANSTOR_DESINTEGRATIVO    object
# TP_SITUACAO                       object
# TP_COR_RACA                       object
# CO_UF_NASCIMENTO                  object
# NO_CURSO                          object
# dtypes: object(19)
# memory usage: 1.7+ GB

# %%
# Identificando dados faltantes

aluno_curso.isnull().sum()
# Out:
# CO_CURSO                                 0
# CO_IES                                   0
# CO_ALUNO_CURSO                           0
# TP_DEFICIENCIA                           0
# IN_DEFICIENCIA_AUDITIVA           11524223
# IN_DEFICIENCIA_FISICA             11524223
# IN_DEFICIENCIA_INTELECTUAL        11524223
# IN_DEFICIENCIA_MULTIPLA           11524223
# IN_DEFICIENCIA_SURDEZ             11524223
# IN_DEFICIENCIA_SURDOCEGUEIRA      11524223
# IN_DEFICIENCIA_BAIXA_VISAO        11524223
# IN_DEFICIENCIA_CEGUEIRA           11524223
# IN_DEFICIENCIA_SUPERDOTACAO       11524223
# IN_TGD_AUTISMO_INFANTIL           11524223
# IN_TGD_TRANSTOR_DESINTEGRATIVO    11524223
# TP_SITUACAO                              0
# TP_COR_RACA                              0
# CO_UF_NASCIMENTO                   3410099
# NO_CURSO                                 0
# dtype: int64

# %%
# Substituindo os dados faltantes pela expressão "Não se aplica" e "Não informado"

aluno_curso.update(aluno_curso['IN_DEFICIENCIA_AUDITIVA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_FISICA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_INTELECTUAL'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_MULTIPLA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_SURDEZ'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_SURDOCEGUEIRA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_BAIXA_VISAO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_CEGUEIRA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_SUPERDOTACAO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_TGD_AUTISMO_INFANTIL'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_TGD_TRANSTOR_DESINTEGRATIVO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['CO_UF_NASCIMENTO'].fillna('Não informado'))

# %% [markdown]
# 3º ETAPA - APRESENTAÇÃO DOS RESULTADOS
#
# PROBLEMAS:
#
# 1- IDENTIFICAR A QUANTIDADE DE ALUNOS COM DEFICIÊNCIA QUE CONCLUÍRAM O ENSINO SUPERIOR.
#
# 2- IDENTIFICAR A QUANTIDADE DE ALUNO POR DEFICIÊNCIA
#
# 3- QUAIS OS CURSOS POSSUI DEFICIENTES
#
# 4- QUAIS OS CURSOS QUE MAIS TIVERAM ALUNOS COM DEFICIÊNCIA COM QUE CONCLUIRAM, MATRICULA TRANCADA OU TRANSFERIDA

# %%
#Quantidade de alunos com deficiência que concluiram o Ensino Superior

#Situação Matrícula (TP_SITUACA)
#  6 - Formado
#  3 - Matrícula trancada
#  5 - Transferido 

#Alunos Indigenas (TP_DEFICIENCIA)
#0 - Não
#1 - Sim

def_concluido = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','TP_DEFICIENCIA', 'TP_SITUACAO']]
#def_concluido
print("\n\nAlunos com deficiência que concluiram o ensino superior\n",def_concluido['TP_DEFICIENCIA'].value_counts())
# Out:
# Alunos com deficiência que concluiram o ensino superior
#  1    5060
# Name: TP_DEFICIENCIA, dtype: int64

# %%
#Quantidade de alunos por deficiência  

#Aluno com deficiência (para todos os tipos de deficiência)
#0 - Não
#1 - Sim

qtd_por_def_auditiva = aluno_curso[(aluno_curso.IN_DEFICIENCIA_AUDITIVA == '1')]
qtd_por_def_fisica =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_FISICA == '1')]     
qtd_por_def_intelec =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_INTELECTUAL == '1')]                             
qtd_por_def_multipla = aluno_curso[(aluno_curso.IN_DEFICIENCIA_MULTIPLA == '1')]
qtd_por_def_surdez = aluno_curso[(aluno_curso.IN_DEFICIENCIA_SURDEZ == '1')]
qtd_por_def_surceg =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_SURDOCEGUEIRA == '1')]                       
qtd_por_def_bvisao =   aluno_curso[(aluno_curso.IN_DEFICIENCIA_BAIXA_VISAO == '1')]                         
qtd_por_def_cegueira = aluno_curso[(aluno_curso.IN_DEFICIENCIA_CEGUEIRA == '1')]
qtd_por_def_superdot =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_SUPERDOTACAO == '1')]                              
qtd_por_def_autismo =  aluno_curso[(aluno_curso.IN_TGD_AUTISMO_INFANTIL == '1')]                     
qtd_por_def_desinte =  aluno_curso[(aluno_curso.IN_TGD_TRANSTOR_DESINTEGRATIVO == '1')]    

print("Total de alunos com deficiência auditiva:",len(qtd_por_def_auditiva),
      "\nTotal de alunos com deficiência física:",len(qtd_por_def_fisica),
      "\nTotal de alunos com deficiência intelectual:",len(qtd_por_def_intelec),
      "\nTotal de alunos com deficiência multipla:",len(qtd_por_def_multipla),
      "\nTotal de alunos com deficiência surdez:",len(qtd_por_def_surdez),
      "\nTotal de alunos com deficiência surdocegueira:",len(qtd_por_def_surceg),
      "\nTotal de alunos com deficiência baixa visão:",len(qtd_por_def_bvisao),
      "\nTotal de alunos com deficiência cegueira:",len(qtd_por_def_cegueira),
      "\nTotal de alunos com deficiência Super Dotação:",len(qtd_por_def_superdot),
      "\nTotal de alunos com deficiência Autismo:",len(qtd_por_def_desinte),
      "\nTotal de alunos com transtorno desintegrativo:",len(qtd_por_def_desinte))
# Out:
# Total de alunos com deficiência auditiva: 7572
# Total de alunos com deficiência física: 20146
# Total de alunos com deficiência intelectual: 2724
# Total de alunos com deficiência multipla: 961
# Total de alunos com deficiência surdez: 2857
# Total de alunos com deficiência surdocegueira: 210
# Total de alunos com deficiência baixa visão: 14326
# Total de alunos com deficiência cegueira: 2909
# Total de alunos com deficiência Super Dotação: 1475
# Total de alunos com deficiência Autismo: 298
# Total de alunos com transtorno desintegrativo: 298

# %%
# Quais cursos possui deficiêntes

cursos_def = aluno_curso[aluno_curso.TP_DEFICIENCIA == '1'] [['CO_ALUNO_CURSO','NO_CURSO']]
cursos_def['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes:\n",cursos_def['NO_CURSO'].value_counts())
      
# Quais cursos com maior número de deficientes formados, matricula trancada ou transferida

def_concluido_curso = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_DEFICIENCIA', 'TP_SITUACAO']]
def_concluido_curso['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes que concluiram o ensino superior\n",def_concluido_curso['NO_CURSO'].value_counts()) 

def_trancada_curso = aluno_curso[(aluno_curso.TP_SITUACAO == '3') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_DEFICIENCIA', 'TP_SITUACAO']]
def_trancada_curso['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes com matrículas trancadas\n",def_trancada_curso['NO_CURSO'].value_counts()) 

def_transferencia_curso = aluno_curso[(aluno_curso.TP_SITUACAO == '5') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_DEFICIENCIA', 'TP_SITUACAO']]
def_transferencia_curso['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes com matriculas transferidas\n",def_transferencia_curso['NO_CURSO'].value_counts())
# Out:
# Curso com deficiêntes que concluiram o ensino superior
#  DIREITO                                                                                                5225
# PEDAGOGIA                                                                                              4311
# ADMINISTRAÇÃO                                                                                          4142
# PSICOLOGIA                                                                                             1841
# CIÊNCIAS CONTÁBEIS                                                                                     1813
# EDUCAÇÃO FÍSICA                                                                                        1763
# ENGENHARIA CIVIL                                                                                       1485
# GESTÃO DE RECURSOS HUMANOS                                                                             1226
# SERVIÇO SOCIAL                                                                                         1200
# ENFERMAGEM                                                                                             1010
# HISTÓRIA                                                                                                990
# CIÊNCIAS BIOLÓGICAS                                                                                     886
# MATEMÁTICA                                                                                              834
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                                                                   831
# LETRAS - LIBRAS                                                                                         791
# ARQUITETURA E URBANISMO                                                                                 756
# FISIOTERAPIA                                                                                            735
# MEDICINA                                                                                                667
# NUTRIÇÃO                                                                                                646
# CIÊNCIA DA COMPUTAÇÃO                                                                                   616
# ENGENHARIA DE PRODUÇÃO                                                                                  615
# ENGENHARIA MECÂNICA                                                                                     548
# GEOGRAFIA                                                                                               515
# ENGENHARIA ELÉTRICA                                                                                     513
# PROCESSOS GERENCIAIS                                                                                    504
# MEDICINA VETERINÁRIA                                                                                    502
# SISTEMAS DE INFORMAÇÃO                                                                                  475
# LOGÍSTICA                                                                                               463
# FARMÁCIA                                                                                                432
# ODONTOLOGIA                                                                                             395
#                                                                                                        ...
# EDUCAÇÃO PROFISSIONAL, CIENTÍFICA E TECNOLÓGICA                                                           1
# LETRAS - PORTUGUÊS, E/OU ALEMÃO, E/OU GREGO, E/OU LATIM                                                   1
# LETRAS VERNÁCULAS - LÍNGUA ESTRANGEIRA                                                                    1
# INTERCULTURAL INDÍGENA                                                                                    1
# CIÊNCIAS DA NATUREZA - BIOLOGIA, FÍSICA E QUÍMICA                                                         1
# LETRAS - ITALIANO                                                                                         1
# CINEMA                                                                                                    1
# SERVIÇOS PENAIS                                                                                           1
# MÚSICA - CORDAS                                                                                           1
# LETRAS - TRADUÇÃO ESPANHOL - PORTUGUÊS                                                                    1
# PROGRAMA ESPECIAL DE FORMAÇÃO DE DOCENTE                                                                  1
# MÚSICA - COMPOSIÇÃO E REGÊNCIA                                                                            1
# MATEMÁTICA APLICADA E COMPUTACIONAL                                                                       1
# ENGENHARIA FERROVIÁRIA E METROVIÁRIA                                                                      1
# ENGENHARIA DE COMPUTAÇÃO E INFORMAÇÃO                                                                     1
# TOXICOLOGIA AMBIENTAL                                                                                     1
# GESTÃO EM SISTEMAS E SERVIÇOS DE SAÚDE                                                                    1
# CIÊNCIAS MILITARES                                                                                        1
# NATUROLOGIA                                                                                               1
# MEDIAÇÃO                                                                                                  1
# LETRAS - LATIM                                                                                            1
# MÚSICA - INSTRUMENTO MUSICAL                                                                              1
# PROGRAMA ESPECIAL FORMAÇÃO DE PROFESSORES PARA OS COMPONENTES CURRICULARES DA EDUCAÇÃO PROFISSIONAL       1
# COMUNICAÇÃO SOCIAL - RADIALISMO/RÁDIO/TV                                                                  1
# ABI - LETRAS - LÍNGUA PORTUGUESA                                                                          1
# CIÊNCIAS ATMOSFÉRICAS                                                                                     1
# ABI - COMPOSIÇÃO E REGÊNCIA                                                                               1
# ABI - DESIGN                                                                                              1
# ABI - LETRAS PORTUGUÊS E ESPANHOL                                                                         1
# ENGENHARIA ELETROTÉCNICA                                                                                  1
# Name: NO_CURSO, Length: 674, dtype: int64
#
#
# Curso com deficiêntes que concluiram o ensino superior
#  PEDAGOGIA                                         579
# DIREITO                                           536
# ADMINISTRAÇÃO                                     475
# EDUCAÇÃO FÍSICA                                   203
# GESTÃO DE RECURSOS HUMANOS                        200
# PSICOLOGIA                                        168
# CIÊNCIAS CONTÁBEIS                                161
# ENGENHARIA CIVIL                                  117
# ENFERMAGEM                                        106
# SERVIÇO SOCIAL                                    102
# CIÊNCIAS BIOLÓGICAS                                81
# PROCESSOS GERENCIAIS                               78
# HISTÓRIA                                           74
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS              71
# GESTÃO PÚBLICA                                     60
# ARQUITETURA E URBANISMO                            55
# MATEMÁTICA                                         55
# FISIOTERAPIA                                       54
# LOGÍSTICA                                          54
# MEDICINA                                           52
# NUTRIÇÃO                                           52
# GESTÃO FINANCEIRA                                  46
# LETRAS - LIBRAS                                    45
# GESTÃO DA TECNOLOGIA DA INFORMAÇÃO                 41
# ODONTOLOGIA                                        41
# COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA      41
# CIÊNCIA DA COMPUTAÇÃO                              39
# MEDICINA VETERINÁRIA                               36
# GEOGRAFIA                                          36
# LETRAS - LÍNGUA PORTUGUESA E LIBRAS                35
#                                                  ...
# SAÚDE COLETIVA                                      1
# MODA, DESIGN E ESTILISMO                            1
# CIÊNCIAS - MATEMÁTICA                               1
# PRODUÇÃO MULTIMÍDIA                                 1
# ENGENHARIA INDUSTRIAL MECÂNICA                      1
# LATICÍNIOS                                          1
# LICENCIATURA INTEGRADA EM HISTÓRIA E GEOGRAFIA      1
# LETRAS - LÍNGUA E LITERATURA INGLESA                1
# SUPERIOR DO AUDIOVISUAL                             1
# METEOROLOGIA                                        1
# PRODUÇÃO E POLÍTICA CULTURAL                        1
# LICENCIATURA INTEGRADA EM PORTUGUÊS E INGLÊS        1
# INTERDISCIPLINAR EM SAÚDE                           1
# ENGENHARIA DE AUTOMAÇÃO INDUSTRIAL                  1
# ENGENHARIA NAVAL E OCEÂNICA                         1
# GESTÃO DE POLÍTICAS PÚBLICAS                        1
# EDUCAÇÃO ESPECIAL                                   1
# INFORMÁTICA PARA NEGÓCIOS                           1
# TECNOLOGIA DA INFORMAÇÃO                            1
# LETRAS - ESPANHOL E LITERATURA HISPÂNICA            1
# ARTES                                               1
# PINTURA                                             1
# ENGENHARIA DE AUTOMAÇÃO                             1
# DESENVOLVIMENTO RURAL                               1
# ENOLOGIA                                            1
# DEFESA E GESTÃO ESTRATÉGICA INTERNACIONAL           1
# GESTÃO E ANÁLISE AMBIENTAL                          1
# COMUNICAÇÃO DAS ARTES DO CORPO                      1
# MECÂNICA                                            1
# GEMOLOGIA                                           1
# Name: NO_CURSO, Length: 277, dtype: int64
#
#
# Curso com deficiêntes com matrículas trancadas
#  DIREITO                                                  563
# PEDAGOGIA                                                536
# ADMINISTRAÇÃO                                            500
# PSICOLOGIA                                               225
# CIÊNCIAS CONTÁBEIS                                       222
# ENGENHARIA CIVIL                                         181
# GESTÃO DE RECURSOS HUMANOS                               149
# EDUCAÇÃO FÍSICA                                          146
# SERVIÇO SOCIAL                                           127
# HISTÓRIA                                                 120
# MATEMÁTICA                                                97
# ENFERMAGEM                                                94
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                     89
# CIÊNCIA DA COMPUTAÇÃO                                     87
# NUTRIÇÃO                                                  84
# FISIOTERAPIA                                              83
# ENGENHARIA DE PRODUÇÃO                                    81
# ARQUITETURA E URBANISMO                                   78
# ENGENHARIA MECÂNICA                                       77
# CIÊNCIAS BIOLÓGICAS                                       76
# ENGENHARIA ELÉTRICA                                       61
# SISTEMAS DE INFORMAÇÃO                                    60
# LOGÍSTICA                                                 59
# PROCESSOS GERENCIAIS                                      58
# GESTÃO PÚBLICA                                            57
# MARKETING                                                 53
# MEDICINA VETERINÁRIA                                      48
# GEOGRAFIA                                                 47
# GESTÃO FINANCEIRA                                         45
# CIÊNCIAS ECONÔMICAS                                       44
#                                                         ...
# LINGUÍSTICA                                                1
# CIÊNCIAS ATMOSFÉRICAS                                      1
# AQUACULTURA                                                1
# PRODUÇÃO DE PROJETOS DE EDIFICAÇÕES                        1
# INTERDISCIPLINAR EM CIÊNCIAS DA TERRA - BI/LI              1
# LETRAS LÍNGUA ESTRANGEIRA APLICADA                         1
# INTERDISCIPLINAR EM EDUCAÇÃO NO CAMPO                      1
# ABI - COMPOSIÇÃO E REGÊNCIA                                1
# ENGENHARIA DE SISTEMAS                                     1
# LÍNGUA PORTUGUESA E RESPECTIVAS LITERATURAS                1
# ARTES CÊNICAS                                              1
# PRODUÇÃO FONOGRÁFICA                                       1
# FÍSICA MÉDICA                                              1
# PEDAGOGIA - EDUCAÇÃO DO CAMPO                              1
# GESTÃO DE SEGUROS                                          1
# ABI - FILOSOFIA                                            1
# DANÇA                                                      1
# LICENCIATURA INTERCULTURAL - COMUNICAÇÃO E ARTES           1
# GESTÃO DE TELECOMUNICAÇÕES                                 1
# BIBLIOTECONOMIA E DOCUMENTAÇÃO                             1
# ABI - HISTÓRIA                                             1
# RADIOLOGIA MÉDICA                                          1
# EDUCAÇÃO ESPECIAL                                          1
# LETRAS - LINGUA ESPANHOLA                                  1
# EDUCAÇÃO FÍSICA - ÊNFASE EM EDUCAÇÃO FÍSICA E SAÚDE        1
# PROCESSOS METALÚRGICOS                                     1
# LETRAS - LÍNGUA INGLESA                                    1
# LETRAS - PORTUGUÊS E LITERATURAS DE LÍNGUA PORTUGUESA      1
# LETRAS - PORTUGUÊS E HEBRAICO                              1
# MÚSICA - CANTO                                             1
# Name: NO_CURSO, Length: 284, dtype: int64
#
#
# Curso com deficiêntes com matriculas transferidas
#  ADMINISTRAÇÃO                               56
# DIREITO                                     43
# CIÊNCIAS CONTÁBEIS                          24
# PEDAGOGIA                                   21
# EDUCAÇÃO FÍSICA                             17
# PSICOLOGIA                                  17
# ENGENHARIA CIVIL                            17
# GESTÃO DE RECURSOS HUMANOS                  15
# NUTRIÇÃO                                    14
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS       11
# ENGENHARIA MECÂNICA                         11
# HISTÓRIA                                    11
# ENGENHARIA DE PRODUÇÃO                      10
# FISIOTERAPIA                                10
# ENFERMAGEM                                   9
# ARQUITETURA E URBANISMO                      8
# MARKETING                                    8
# CIÊNCIAS BIOLÓGICAS                          8
# FARMÁCIA                                     7
# SERVIÇO SOCIAL                               7
# CIÊNCIAS ECONÔMICAS                          6
# ENGENHARIA DE COMPUTAÇÃO                     6
# FILOSOFIA                                    6
# BIOMEDICINA                                  6
# SISTEMAS DE INFORMAÇÃO                       6
# DESIGN                                       5
# ABI - FÍSICA                                 4
# GESTÃO FINANCEIRA                            4
# CIÊNCIAS SOCIAIS                             4
# QUÍMICA                                      4
#                                             ..
# QUÍMICA INDUSTRIAL                           1
# ALIMENTOS                                    1
# LETRAS PORTUGUÊS E INGLÊS                    1
# ABI - LETRAS PORTUGUÊS E ESPANHOL            1
# FÍSICA                                       1
# ZOOTECNIA                                    1
# GESTÃO DA PRODUÇÃO INDUSTRIAL                1
# ENGENHARIA DE ENERGIA                        1
# TEOLOGIA                                     1
# SOCIOLOGIA                                   1
# ABI - ARTES VISUAIS                          1
# COMUNICAÇÃO SOCIAL - CINEMA                  1
# ENGENHARIA INDUSTRIAL MECÂNICA               1
# ENGENHARIA DE PRODUÇÃO MECÂNICA              1
# LETRAS - LIBRAS                              1
# ABI - LETRAS FRANCÊS                         1
# GESTÃO DE MICRO E PEQUENAS EMPRESAS          1
# CONSTRUÇÃO DE EDIFÍCIOS                      1
# ABI - CIÊNCIA DA COMPUTAÇÃO                  1
# DESIGN DE INTERIORES                         1
# JORNALISMO                                   1
# MATEMÁTICA - LICENCIATURA OU BACHARELADO     1
# PINTURA                                      1
# GESTÃO DA TECNOLOGIA DA INFORMAÇÃO           1
# ENGENHARIA FLORESTAL                         1
# LETRAS - PORTUGUÊS E ALEMÃO                  1
# SISTEMA DE INFORMAÇÃO                        1
# HISTÓRIA - AMÉRICA LATINA                    1
# DESIGN VISUAL                                1
# LETRAS - INGLÊS                              1
# Name: NO_CURSO, Length: 119, dtype: int64

# %% [markdown]
# QUESTÕES SOBRE INDIGENAS
#
# 5- QUAL QUANTIDADE DE ALUNOS INDIGENAS QUE CONCLUÍRAM O ENSINO SUPERIOR
#
# 6- QUAL A QUANTIDADE DE ALUNO INDIGENAS POR CURSO
#
# 7- QUAIS OS CURSOS QUE MAIS TIVERAM ALUNOS INDIGENAS FORMADOS, COM MATRICULA TRANCADA OU TRANSFERIDA

# %%
#Quantidade de alunos Indígena que concluiram o Ensino Superior

#Situação Matrícula (TP_SITUACA)
#  6 - Formado
#  3 - Matrícula trancada
#  5 - Transferido 

#Aluno Indígena (TP_COR_RACA)
#5 - Indígena

total_aluno_indigena = aluno_curso[(aluno_curso.TP_COR_RACA == '5')]

print("Alunos Indígenas que cursam o Ensino Superior em 2017:",len(total_aluno_indigena))
                                   
aluno_indigena = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_COR_RACA == '5')] [['CO_ALUNO_CURSO','TP_COR_RACA','TP_SITUACAO']]
#aluno_indigena
print("\n\nAlunos Indígenas que concluiram o Ensino Superior:",len(aluno_indigena))
# Out:
# Alunos Indígenas que cursam o Ensino Superior em 2017: 83155
#
#
# Alunos Indígenas que concluiram o Ensino Superior: 4954

# %%
#Cursos que possui Indígenas

cursos_indigena = aluno_curso[aluno_curso.TP_COR_RACA == '5'] [['CO_ALUNO_CURSO','NO_CURSO']]
cursos_indigena['NO_CURSO'].value_counts()
print("\n\nCursos que possui Indígenas\n",cursos_indigena['NO_CURSO'].value_counts())
# Out:
# Cursos que possui Indígenas
#  DIREITO                                                        7909
# PEDAGOGIA                                                      6837
# ADMINISTRAÇÃO                                                  5081
# ENFERMAGEM                                                     4195
# ENGENHARIA CIVIL                                               3864
# CIÊNCIAS CONTÁBEIS                                             3153
# EDUCAÇÃO FÍSICA                                                3139
# PSICOLOGIA                                                     2912
# NUTRIÇÃO                                                       2743
# FISIOTERAPIA                                                   2499
# FARMÁCIA                                                       2102
# ODONTOLOGIA                                                    1646
# GESTÃO DE RECURSOS HUMANOS                                     1645
# SERVIÇO SOCIAL                                                 1310
# ARQUITETURA E URBANISMO                                        1141
# BIOMEDICINA                                                    1094
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                          1083
# LOGÍSTICA                                                      1077
# ENGENHARIA DE PRODUÇÃO                                         1060
# LICENCIATURA INTERCULTURAL INDÍGENA                            1027
# CIÊNCIAS BIOLÓGICAS                                             976
# ENGENHARIA MECÂNICA                                             953
# HISTÓRIA                                                        909
# ENGENHARIA ELÉTRICA                                             803
# MATEMÁTICA                                                      795
# GASTRONOMIA                                                     734
# MEDICINA VETERINÁRIA                                            687
# GEOGRAFIA                                                       636
# MEDICINA                                                        589
# CIÊNCIA DA COMPUTAÇÃO                                           516
#                                                                ...
# CIÊNCIAS MOLECULARES                                              1
# ENGENHARIA DE EXPLORAÇÃO E PRODUÇÃO DE PETRÓLEO                   1
# LETRAS - JAPONÊS                                                  1
# SISTEMAS NAVAIS                                                   1
# AUDIOVISUAL                                                       1
# ECONOMIA DOMÉSTICA                                                1
# ENGENHARIA MECÂNICA AUTOMOTIVA                                    1
# MATEMÁTICA APLICADA                                               1
# ABI - LETRAS PORTUGUÊS E ESPANHOL                                 1
# ENGENHARIA DE BIOPROCESSOS                                        1
# MÚSICA - PIANO                                                    1
# ENOLOGIA                                                          1
# ÓPTICA E OPTOMETRIA                                               1
# DESIGN DE ANIMAÇÃO                                                1
# COMUNICAÇÃO SOCIAL - CINEMA                                       1
# ARTES CÊNICAS COM HABILITAÇÃO EM DIREÇÃO TEATRAL                  1
# ENGENHARIA DE PRODUÇÃO QUÍMICA                                    1
# SOCIOLOGIA E POLÍTICA                                             1
# ENGENHARIA DE AGRONEGÓCIOS                                        1
# AUTOMAÇÃO E MANUFATURA DIGITAL                                    1
# FORMAÇÃO PEDAGÓGICA PARA PORTADORES DE ENSINO SUPERIOR            1
# CIÊNCIAS: BIOLOGIA, FÍSICA E QUÍMICA                              1
# SERVIÇOS JURÍDICOS E NOTARIAIS                                    1
# OBSTETRÍCIA                                                       1
# FÍSICA MÉDICA                                                     1
# LETRAS: INGLÊS                                                    1
# ABI - LITERATURAS DE LÍNGUA PORTUGUESA                            1
# ENGENHARIA CIVIL EMPRESARIAL                                      1
# LICENCIATURA INTEGRADA EM CIÊNCIAS, MATEMÁTICA E LINGUAGENS       1
# ENGENHARIA DE TELEINFORMÁTICA                                     1
# Name: NO_CURSO, Length: 652, dtype: int64

# %%
# Quais cursos com maior número de Indígenas formados, matricula trancada ou transferida

cursos_indigena_formado = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_COR_RACA == '5' )] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
cursos_indigena_formado['NO_CURSO'].value_counts()
print("\n\nCurso com Indígenas que concluiram o ensino superior\n",cursos_indigena_formado['NO_CURSO'].value_counts()) 

cursos_indigena_trancada = aluno_curso[(aluno_curso.TP_SITUACAO == '3') & (aluno_curso.TP_COR_RACA == '5')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
cursos_indigena_trancada['NO_CURSO'].value_counts()
print("\n\nCurso com Indígenas com matrículas trancadas\n",cursos_indigena_trancada['NO_CURSO'].value_counts()) 

cursos_indigena_transferido = aluno_curso[(aluno_curso.TP_SITUACAO == '5') & (aluno_curso.TP_COR_RACA == '5')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
cursos_indigena_transferido['NO_CURSO'].value_counts()
print("\n\nCurso com Indígenas com matriculas transferidas\n",cursos_indigena_transferido['NO_CURSO'].value_counts())
# Out:
# Curso com Indígenas que concluiram o ensino superior
#  DIREITO                                                            717
# ADMINISTRAÇÃO                                                      355
# PEDAGOGIA                                                          302
# ENGENHARIA CIVIL                                                   217
# EDUCAÇÃO FÍSICA                                                    191
# CIÊNCIAS CONTÁBEIS                                                 166
# ENFERMAGEM                                                         159
# GESTÃO DE RECURSOS HUMANOS                                         149
# LICENCIATURA INTERCULTURAL INDÍGENA                                142
# SERVIÇO SOCIAL                                                     114
# FISIOTERAPIA                                                       110
# LOGÍSTICA                                                           93
# CIÊNCIAS BIOLÓGICAS                                                 92
# PSICOLOGIA                                                          84
# GASTRONOMIA                                                         80
# ARQUITETURA E URBANISMO                                             78
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                               60
# MATEMÁTICA                                                          54
# JORNALISMO                                                          51
# LETRAS - LÍNGUA PORTUGUESA                                          50
# MEDICINA                                                            48
# HISTÓRIA                                                            46
# ODONTOLOGIA                                                         45
# NUTRIÇÃO                                                            44
# RELAÇÕES INTERNACIONAIS                                             43
# CIÊNCIAS SOCIAIS                                                    39
# GESTÃO FINANCEIRA                                                   37
# GEOGRAFIA                                                           35
# COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA                       32
# FONOAUDIOLOGIA                                                      32
#                                                                   ...
# PRODUÇÃO MULTIMÍDIA                                                  1
# BANCO DE DADOS                                                       1
# CIÊNCIAS BIOLÓGICAS - ZOOLOGIA                                       1
# ENGENHARIA CIVIL DE INFRAESTRUTURA                                   1
# OCEANOGRAFIA                                                         1
# ENGENHARIA AEROESPACIAL                                              1
# ENGENHARIA BIOENERGÉTICA                                             1
# ETNODESENVOLVIMENTO                                                  1
# QUÍMICA TECNOLÓGICA                                                  1
# AGRONEGÓCIO                                                          1
# ENGENHARIA DE PETRÓLEO                                               1
# LETRAS - PORTUGUÊS E FRANCÊS                                         1
# ENGENHARIA DE RECURSOS HÍDRICOS E DO MEIO AMBIENTE                   1
# LETRAS - LÍNGUA E LITERATURA INGLESA                                 1
# EMBELEZAMENTO E IMAGEM PESSOAL                                       1
# MECATRÔNICA INDUSTRIAL                                               1
# LETRAS - FRANCÊS                                                     1
# NEGÓCIOS IMOBILIÁRIOS                                                1
# EDUCAÇÃO FÍSICA - TREINAMENTO ESPORTIVO                              1
# CIÊNCIAS DA NATUREZA                                                 1
# PROGRAMA ESPECIAL DE FORMAÇÃO PEDAGÓGICA DE DOCENTES - BIOLOGIA      1
# GESTÃO PÚBLICA E DESENVOLVIMENTO REGIONAL                            1
# DESENHO INDUSTRIAL                                                   1
# CIÊNCIAS AGRÁRIAS E DO AMBIENTE                                      1
# CIÊNCIAS - FÍSICA                                                    1
# SEGURANÇA DA INFORMAÇÃO                                              1
# ENGENHARIA MECATRÔNICA                                               1
# EDUCAÇÃO ARTÍSTICA COM HABILITAÇÃO EM ARTES PLÁSTICAS                1
# SAÚDE COLETIVA                                                       1
# ARTES VISUAIS - PROGRAMA SEGUNDA LICENCIATURA                        1
# Name: NO_CURSO, Length: 248, dtype: int64
#
#
# Curso com Indígenas com matrículas trancadas
#  ADMINISTRAÇÃO                                            681
# DIREITO                                                  628
# PEDAGOGIA                                                596
# ENGENHARIA CIVIL                                         584
# CIÊNCIAS CONTÁBEIS                                       429
# ENFERMAGEM                                               369
# NUTRIÇÃO                                                 338
# EDUCAÇÃO FÍSICA                                          272
# PSICOLOGIA                                               263
# GESTÃO DE RECURSOS HUMANOS                               261
# FISIOTERAPIA                                             233
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                    212
# ENGENHARIA DE PRODUÇÃO                                   181
# LOGÍSTICA                                                155
# SERVIÇO SOCIAL                                           141
# LETRAS                                                   126
# FARMÁCIA                                                 112
# HISTÓRIA                                                 111
# ARQUITETURA E URBANISMO                                  107
# PROCESSOS GERENCIAIS                                     101
# MARKETING                                                100
# ODONTOLOGIA                                               99
# ENGENHARIA ELÉTRICA                                       95
# GESTÃO TERRITORIAL INDÍGENA                               92
# MATEMÁTICA                                                92
# BIOMEDICINA                                               90
# ENGENHARIA MECÂNICA                                       87
# GESTÃO FINANCEIRA                                         83
# CIÊNCIAS BIOLÓGICAS                                       72
# GEOGRAFIA                                                 61
#                                                         ...
# COMPUTAÇÃO E INFORMÁTICA                                   1
# ESTUDOS DE MÍDIA                                           1
# INTERDISCIPLINAR EM CIÊNCIAS DA TERRA - BI/LI              1
# LETRAS - PORTUGUÊS E LITERATURAS DE LÍNGUA PORTUGUESA      1
# LETRAS - LÍNGUA PORTUGUESA E LIBRAS                        1
# NEGÓCIOS DA MODA                                           1
# LETRAS - ESPANHOL E LITERATURA HISPÂNICA                   1
# CIÊNCIAS JURÍDICAS E SOCIAIS                               1
# LINGUAGENS E CÓDIGOS - LÍNGUA PORTUGUESA                   1
# DESENHO DE ANIMAÇÃO                                        1
# BIBLIOTECONOMIA E GESTÃO DE UNIDADES DE INFORMAÇÃO         1
# MÚSICA - CORDAS                                            1
# INTERDISCIPLINAR EM CIÊNCIAS DO TRABALHO                   1
# ESTATÍSTICA                                                1
# MANUTENÇÃO INDUSTRIAL                                      1
# CIÊNCIAS AGRÍCOLAS                                         1
# LETRAS - TRADUTOR E INTÉRPRETE                             1
# CIÊNCIAS SOCIAIS - POLÍTICAS PÚBLICAS                      1
# IRRIGAÇÃO E DRENAGEM                                       1
# ESTÉTICA E IMAGEM PESSOAL                                  1
# MARKETING DIGITAL                                          1
# GESTÃO DE SEGUROS                                          1
# SERVIÇOS PENAIS                                            1
# ABI - FILOSOFIA                                            1
# EDUCAÇÃO ARTÍSTICA COM HABILITAÇÃO EM ARTES PLÁSTICAS      1
# PROCESSOS ESCOLARES                                        1
# CIÊNCIAS HUMANAS - SOCIOLOGIA                              1
# INTERCULTURAL INDÍGENA EM CIÊNCIAS SOCIAIS                 1
# TECNOLOGIAS DA INFORMAÇÃO E COMUNICAÇÃO                    1
# LETRAS - LÍNGUA PORTUGUESA COM DOMÍNIO DE LIBRAS           1
# Name: NO_CURSO, Length: 287, dtype: int64
#
#
# Curso com Indígenas com matriculas transferidas
#  ABI - LICENCIATURA INTERCULTURAL                 99
# ABI - EDUCAÇÃO INTERCULTURAL                     61
# ADMINISTRAÇÃO                                    35
# DIREITO                                          30
# EDUCAÇÃO FÍSICA                                  25
# ENGENHARIA CIVIL                                 20
# PEDAGOGIA                                        17
# CIÊNCIAS CONTÁBEIS                               15
# ABI - GEOGRAFIA                                  12
# PSICOLOGIA                                       12
# CIÊNCIA DA COMPUTAÇÃO                             9
# ABI - LICENCIATURAS INTERDISCIPLINARES            8
# ENFERMAGEM                                        8
# ARQUITETURA E URBANISMO                           8
# ENGENHARIA DE PRODUÇÃO                            7
# NUTRIÇÃO                                          7
# BIOMEDICINA                                       7
# ENGENHARIA MECÂNICA                               6
# GESTÃO DE RECURSOS HUMANOS                        6
# ENGENHARIA                                        5
# LOGÍSTICA                                         5
# SISTEMAS DE INFORMAÇÃO                            5
# QUÍMICA                                           5
# COMUNICAÇÃO SOCIAL - JORNALISMO                   5
# FISIOTERAPIA                                      4
# CIÊNCIAS BIOLÓGICAS                               4
# COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA     4
# ENGENHARIA AMBIENTAL                              4
# CIÊNCIAS ECONÔMICAS                               4
# ENGENHARIA ELÉTRICA                               4
#                                                  ..
# ABI - COMUNICAÇÃO SOCIAL                          1
# GESTÃO DE SERVIÇOS JURÍDICOS E NOTARIAIS          1
# GASTRONOMIA                                       1
# BIOTECNOLOGIA                                     1
# ENGENHARIA DE TELEINFORMÁTICA                     1
# INTERDISCIPLINAR EM HUMANIDADES                   1
# ENGENHARIA DE PETRÓLEO                            1
# COMÉRCIO EXTERIOR                                 1
# LETRAS - PORTUGUÊS E INGLÊS                       1
# DESIGN                                            1
# RELAÇÕES INTERNACIONAIS                           1
# REDES DE COMPUTADORES                             1
# MEDICINA                                          1
# ABI - LETRAS ALEMÂO                               1
# INTERDISCIPLINAR EM CIÊNCIA E TECNOLOGIA          1
# ABI - ARTES VISUAIS                               1
# FARMÁCIA E BIOQUÍMICA                             1
# CIÊNCIA ECONÔMICA                                 1
# PETRÓLEO E GÁS                                    1
# ENGENHARIA FLORESTAL                              1
# ECONOMIA ECOLÓGICA                                1
# ABI - CIÊNCIA DA COMPUTAÇÃO                       1
# COMUNICAÇÃO SOCIAL - RADIALISMO (RÁDIO E TV)      1
# ENGENHARIA DE ENERGIA                             1
# MÚSICA - PIANO                                    1
# INFORMÁTICA                                       1
# RELAÇÕES PÚBLICAS                                 1
# ENGENHARIA DE MATERIAIS                           1
# SISTEMAS PARA INTERNET                            1
# ODONTOLOGIA                                       1
# Name: NO_CURSO, Length: 104, dtype: int64
