# %% [markdown]
# ANÁLISE DE DADOS UTILIZANDO PYTHON
#
# 1º EATAPA - DADOS
#
# Será realizada a análise de dados referente a Educação Superior no Brasil, para isso, foram utilizadas base de dados disponibilizadas pelo Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira Legislação e Documentos - INEP.
#
# Diante da diversidade que há no Brasil e da atual discusão referente a inclusão social e a adoção de politicas públicas em prol das minorias. Esta análise visa identificar o quantitativo de alunos indigenas e com deficiência que concluíram um curso superior entre o período de 2013 a 2017 no Brasil. Bem como a relação desse quantitativo com o quantitativo global da população indigena e da população de pessoas com deficiência.
#
# Foram utilizados os dados diponíveis no link: http://portal.inep.gov.br/microdados, opção Censo da Educação superior, anos de 2013 a 2017.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

#Extraindo as bases ano 2017

#Ano 2017
#data_ies = pd.read_csv("Desktop\Dados\ies.csv", sep="|", encoding="ANSI")
#data_ies
data_curso = pd.read_csv("Desktop\Dados\curso.csv", sep="|", dtype=object, encoding="ANSI")
#data_curso
#data_docente = pd.read_csv("Desktop\Dados\docente.csv", sep="|", encoding="ANSI")
#data_docente
#data_local_oferta = pd.read_csv("Desktop\Dados\local_oferta.csv", sep="|", encoding="ANSI")
#data_local_oferta
Diretorio= r"Desktop\Dados\aluno.csv"
data_aluno = pd.read_csv(Diretorio, sep="|", dtype=object, encoding="ANSI")


#data_aluno = pd.DataFrame(data_aluno,columns=['IN_TGD_AUTISMO'])

# %% [markdown]
# 2º ETAPA - TRATAMENTO DOS DADOS
#
# 2.1 LIMPEZA E PREPARAÇÃO DOS DADOS
#
# Nesta etapa foram tratados:
# - Os dados foram manipulados realizando a junção e combinação entre tabelas.
# - Os dados ausentes.
# - Foram identificados os dados ausentes e substituídos por dados.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

#Criando Data Frame com as colunas necessárias e juntatando as colunas que serão utilizadas

aluno = pd.DataFrame(data_aluno, columns=['CO_OCDE','CO_CURSO','CO_ALUNO_CURSO','TP_DEFICIENCIA','IN_DEFICIENCIA_AUDITIVA',
                                          'IN_DEFICIENCIA_FISICA','IN_DEFICIENCIA_INTELECTUAL','IN_DEFICIENCIA_MULTIPLA',
                                          'IN_DEFICIENCIA_SURDEZ','IN_DEFICIENCIA_SURDOCEGUEIRA','IN_DEFICIENCIA_BAIXA_VISAO',
                                          'IN_DEFICIENCIA_CEGUEIRA','IN_DEFICIENCIA_SUPERDOTACAO','IN_TGD_AUTISMO',
                                          'IN_TGD_TRANSTOR_DESINTEGRATIVO','TP_SITUACAO','TP_COR_RACA','CO_UF_NASCIMENTO'])


curso = pd.DataFrame(data_curso, columns=['CO_OCDE','CO_CURSO' ,'NO_CURSO'])

aluno_curso=pd.merge(curso, aluno, left_index=True, right_index=True)

#Renomeando as colunas 

#aluno.columns = ['Código OCDE Aluno', 'Código do curso ', 'Código Aluno por curso', 'Aluno com Deficiência ', 
#'Deficiência auditiva', 'Deficiência física', 'Deficiência intelectual','Deficiência Multipla', 'Deficiência Surdez',
#'Deficiência Surdocegueira', 'Deficiência Baixa Visão', 'Deficiência Cegueira', 'Deficiência Superdotação', 'Autismo',
#'Transtorno desintegrativo', 'Situação Matrícula', 'Raça/Cor', 'UF de Nascimento']
#curso.columns = ['Código OCDE Curso ', 'Código do Curso', 'Nome do curso']

# Identificando dados faltantes

aluno_curso.isnull().sum()

# Substituindo os dados faltantes pela expressão "Não se aplica" e "Não informado"

aluno_curso.update(aluno_curso['IN_DEFICIENCIA_AUDITIVA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_FISICA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_INTELECTUAL'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_MULTIPLA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_SURDEZ'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_SURDOCEGUEIRA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_BAIXA_VISAO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_CEGUEIRA'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_DEFICIENCIA_SUPERDOTACAO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_TGD_AUTISMO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['IN_TGD_TRANSTOR_DESINTEGRATIVO'].fillna('Não se aplica'))
aluno_curso.update(aluno_curso['CO_UF_NASCIMENTO'].fillna('Não informado'))
aluno_curso.update(aluno_curso['CO_OCDE_x'].fillna('Não localizado'))


# Substituindo valores pela descrição (Alteração realizada com base no dicionário que acompanha a base de dados)

# %% [markdown]
# 3º ETAPA - APRESENTAÇÃO DOS RESULTADOS
#
# PROBLEMAS:
#
# 1- IDENTIFICAR A QUANTIDADE DE ALUNOS COM DEFICIÊNCIA QUE CONCLUÍRAM O ENSINO SUPERIOR.
#
# 2- IDENTIFICAR A QUANTIDADE DE ALUNO POR DEFICIÊNCIA
#
# 3- QUAIS OS CURSOS POSSUI DEFICIENTES
#
# 4- QUAIS OS CURSOS QUE MAIS TIVERAM ALUNOS COM DEFICIÊNCIA COM QUE CONCLUIRAM, MATRICULA TRANCADA OU TRANSFERIDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

#Quantidade de alunos com deficiência que concluiram o Ensino Superior

#Situação Matrícula (TP_SITUACA)
#  6 - Formado
#  3 - Matrícula trancada
#  5 - Transferido 

#Alunos Indigenas (TP_DEFICIENCIA)
#0 - Não
#1 - Sim

qtd_def_concluido = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','TP_DEFICIENCIA', 'TP_SITUACAO']]
qtd_def_concluido
print("Total de Alunos formados que possui deficiência:",len(qtd_def_concluido))


#Quantidade de alunos por deficiência  

#Aluno com deficiência (para todos os tipos de deficiência)
#0 - Não
#1 - Sim

qtd_por_def_auditiva = aluno_curso[(aluno_curso.IN_DEFICIENCIA_AUDITIVA == '1')]
qtd_por_def_fisica =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_FISICA == '1')]     
qtd_por_def_intelec =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_INTELECTUAL == '1')]                             
qtd_por_def_multipla = aluno_curso[(aluno_curso.IN_DEFICIENCIA_MULTIPLA == '1')]
qtd_por_def_surdez = aluno_curso[(aluno_curso.IN_DEFICIENCIA_SURDEZ == '1')]
qtd_por_def_surceg =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_SURDOCEGUEIRA == '1')]                       
qtd_por_def_bvisao =   aluno_curso[(aluno_curso.IN_DEFICIENCIA_BAIXA_VISAO == '1')]                         
qtd_por_def_cegueira = aluno_curso[(aluno_curso.IN_DEFICIENCIA_CEGUEIRA == '1')]
qtd_por_def_superdot =  aluno_curso[(aluno_curso.IN_DEFICIENCIA_SUPERDOTACAO == '1')]                              
qtd_por_def_autismo =  aluno_curso[(aluno_curso.IN_TGD_AUTISMO == '1')]                     
qtd_por_def_desinte =  aluno_curso[(aluno_curso.IN_TGD_TRANSTOR_DESINTEGRATIVO == '1')]    

print("Total de alunos com deficiência auditiva:",len(qtd_por_def_auditiva),
      "\nTotal de alunos com deficiência física:",len(qtd_por_def_fisica),
     "\nTotal de alunos com deficiência intelectual:",len(qtd_por_def_intelec),
   "\nTotal de alunos com deficiência multipla:",len(qtd_por_def_multipla),
    "\nTotal de alunos com deficiência surdez:",len(qtd_por_def_surdez),
    "\nTotal de alunos com deficiência surdocegueira:",len(qtd_por_def_surceg),
    "\nTotal de alunos com deficiência baixa visão:",len(qtd_por_def_bvisao),
    "\nTotal de alunos com deficiência cegueira:",len(qtd_por_def_cegueira),
    "\nTotal de alunos com deficiência Super Dotação:",len(qtd_por_def_superdot),
    "\nTotal de alunos com deficiência Autismo:",len(qtd_por_def_desinte),
       "\nTotal de alunos com transtorno desintegrativo:",len(qtd_por_def_desinte))
   
# Quais cursos possui deficiêntes

cursos_def = aluno_curso[aluno_curso.TP_DEFICIENCIA == '1'] [['CO_ALUNO_CURSO','NO_CURSO']]
cursos_def['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes que concluiram o ensino superior\n",cursos_def['NO_CURSO'].value_counts())
      
# Quais cursos com maior número de deficientes formados, matricula trancada ou transferida

def_concluido_curso = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_DEFICIENCIA', 'TP_SITUACAO']]
def_concluido_curso['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes que concluiram o ensino superior\n",def_concluido_curso['NO_CURSO'].value_counts()) 

def_trancada_curso = aluno_curso[(aluno_curso.TP_SITUACAO == '3') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_DEFICIENCIA', 'TP_SITUACAO']]
def_trancada_curso['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes com matrículas trancadas\n",def_trancada_curso['NO_CURSO'].value_counts()) 

def_transferencia_curso = aluno_curso[(aluno_curso.TP_SITUACAO == '5') & (aluno_curso.TP_DEFICIENCIA == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_DEFICIENCIA', 'TP_SITUACAO']]
def_transferencia_curso['NO_CURSO'].value_counts()
print("\n\nCurso com deficiêntes com matriculas transferidas\n",def_transferencia_curso['NO_CURSO'].value_counts())
# Out:
# Total de Alunos formados que possui deficiência: 8
# Total de alunos com deficiência auditiva: 29
# Total de alunos com deficiência física: 76
# Total de alunos com deficiência intelectual: 8
# Total de alunos com deficiência multipla: 1
# Total de alunos com deficiência surdez: 22
# Total de alunos com deficiência surdocegueira: 0
# Total de alunos com deficiência baixa visão: 46
# Total de alunos com deficiência cegueira: 6
# Total de alunos com deficiência Super Dotação: 0
# Total de alunos com deficiência Autismo: 1
# Total de alunos com transtorno desintegrativo: 1
#
#
# Curso com deficiêntes que concluiram o ensino superior
#  PEDAGOGIA                                                                 11
# CIÊNCIAS CONTÁBEIS                                                         8
# EDUCAÇÃO FÍSICA                                                            8
# ADMINISTRAÇÃO                                                              8
# ARQUITETURA E URBANISMO                                                    8
# DIREITO                                                                    6
# FISIOTERAPIA                                                               6
# ENGENHARIA DE PRODUÇÃO                                                     6
# CIÊNCIAS BIOLÓGICAS                                                        5
# FARMÁCIA                                                                   5
# NUTRIÇÃO                                                                   5
# BIOMEDICINA                                                                4
# SERVIÇO SOCIAL                                                             4
# ENFERMAGEM                                                                 4
# PSICOLOGIA                                                                 4
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                                      4
# MEDICINA VETERINÁRIA                                                       3
# ENGENHARIA CIVIL                                                           3
# LETRAS - INGLÊS                                                            3
# COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA                              3
# QUÍMICA                                                                    3
# GESTÃO DE RECURSOS HUMANOS                                                 3
# AGRONOMIA                                                                  3
# TURISMO                                                                    2
# ENGENHARIA ELÉTRICA                                                        2
# GEOGRAFIA                                                                  2
# MARKETING                                                                  2
# ALIMENTOS                                                                  2
# MEDICINA                                                                   2
# LETRAS - PORTUGUÊS E INGLÊS                                                2
#                                                                           ..
# COMUNICAÇÃO SOCIAL                                                         1
# CIÊNCIAS ECONÔMICAS                                                        1
# ENGENHARIA AMBIENTAL E SANITÁRIA                                           1
# FILOSOFIA                                                                  1
# LETRAS - PORTUGUÊS E ALEMÃO                                                1
# CIÊNCIAS: BIOLOGIA, FÍSICA E QUÍMICA                                       1
# ESTÉTICA E COSMÉTICA                                                       1
# ENGENHARIA DE ALIMENTOS                                                    1
# INTERDISCIPLINAR EM SAÚDE - BI/LI                                          1
# GESTÃO DE PRODUÇÃO INDUSTRIAL                                              1
# ARQUEOLOGIA                                                                1
# REDES DE COMPUTADORES                                                      1
# AGRONEGÓCIO                                                                1
# GESTÃO DA QUALIDADE                                                        1
# PRODUÇÃO GRÁFICA                                                           1
# CIÊNCIA E TECNOLOGIA DE ALIMENTOS                                          1
# COMÉRCIO EXTERIOR                                                          1
# RELAÇÕES PÚBLICAS                                                          1
# ABI - CIÊNCIAS BIOMÉDICAS                                                  1
# ABI - CIÊNCIAS BIOLÓGICAS                                                  1
# ENGENHARIA INDUSTRIAL MADEIREIRA                                           1
# LETRAS - LÍNGUA ESTRANGEIRA                                                1
# GEOPROCESSAMENTO                                                           1
# POLÍMEROS                                                                  1
# ESTATÍSTICA                                                                1
# LETRAS - LÍNGUAS ADICIONAIS INGLÊS, ESPANHOL E RESPECTIVAS LITERATURAS     1
# CIÊNCIAS - MATEMÁTICA E FÍSICA                                             1
# GASTRONOMIA                                                                1
# LETRAS - PORTUGUÊS E LITERATURAS DE LÍNGUA PORTUGUESA                      1
# LETRAS - ESPANHOL                                                          1
# Name: NO_CURSO, Length: 86, dtype: int64
#
#
# Curso com deficiêntes que concluiram o ensino superior
#  ANÁLISE E DESENVOLVIMENTO DE SISTEMAS    2
# BIOMEDICINA                              1
# CIÊNCIA DA COMPUTAÇÃO                    1
# LETRAS - ESPANHOL                        1
# MARKETING                                1
# GESTÃO DE RECURSOS HUMANOS               1
# LETRAS - LÍNGUA ESTRANGEIRA              1
# Name: NO_CURSO, dtype: int64
#
#
# Curso com deficiêntes com matrículas trancadas
#  CIÊNCIAS CONTÁBEIS                                       6
# MEDICINA VETERINÁRIA                                     3
# ARQUITETURA E URBANISMO                                  3
# FARMÁCIA                                                 3
# ENFERMAGEM                                               2
# PEDAGOGIA                                                2
# ENGENHARIA CIVIL                                         1
# CIÊNCIAS - MATEMÁTICA E FÍSICA                           1
# LETRAS - LÍNGUA PORTUGUESA                               1
# FISIOTERAPIA                                             1
# GESTÃO DA QUALIDADE                                      1
# GESTÃO DA TECNOLOGIA DA INFORMAÇÃO                       1
# BIOMEDICINA                                              1
# ENGENHARIA DE PRODUÇÃO                                   1
# GESTÃO DE RECURSOS HUMANOS                               1
# ESTATÍSTICA                                              1
# PROCESSOS GERENCIAIS                                     1
# SERVIÇO SOCIAL                                           1
# LOGÍSTICA                                                1
# ENGENHARIA MECÂNICA                                      1
# ARQUEOLOGIA                                              1
# DIREITO                                                  1
# MATEMÁTICA                                               1
# LETRAS - PORTUGUÊS E LITERATURAS DE LÍNGUA PORTUGUESA    1
# JORNALISMO                                               1
# COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA            1
# EDUCAÇÃO FÍSICA                                          1
# GEOPROCESSAMENTO                                         1
# AGRONOMIA                                                1
# CIÊNCIAS BIOLÓGICAS                                      1
# GEOGRAFIA                                                1
# MÚSICA                                                   1
# ENGENHARIA AMBIENTAL E SANITÁRIA                         1
# NUTRIÇÃO                                                 1
# CIÊNCIAS BIOLÓGICAS: MODALIDADE MÉDICA                   1
# LETRAS - INGLÊS                                          1
# AUTOMAÇÃO INDUSTRIAL                                     1
# QUÍMICA                                                  1
# GESTÃO DA PRODUÇÃO INDUSTRIAL                            1
# ENGENHARIA AMBIENTAL                                     1
# Name: NO_CURSO, dtype: int64
#
#
# Curso com deficiêntes com matriculas transferidas
#  Series([], Name: NO_CURSO, dtype: int64)

# %% [markdown]
# 5- QUAL QUANTIDADE DE ALUNOS INDIGENAS QUE CONCLUÍRAM O ENSINO SUPERIOR
#
# 6- QUAL A QUANTIDADE DE ALUNO INDIGENAS POR CURSO
#
# 7- QUAIS OS CURSOS QUE MAIS TIVERAM ALUNOS INDIGENAS FORMADOS, COM MATRICULA TRANCADA OU TRANSFERIDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

#Quantidade de alunos Indígena que concluiram o Ensino Superior

#Situação Matrícula (TP_SITUACA)
#  6 - Formado
#  3 - Matrícula trancada
#  5 - Transferido 

#Aluno Indígena (TP_COR_RACA)
#5 - Indígena


aluno_indigena = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_COR_RACA == '5')] [['CO_ALUNO_CURSO','TP_COR_RACA','TP_SITUACAO']]
aluno_indigena
print("Alunos Indígenas que concluiram o Ensino Superior:",len(aluno_indigena))

 
#Cursos que possui Indígenas

cursos_indigena = aluno_curso[aluno_curso.TP_COR_RACA == '5'] [['CO_ALUNO_CURSO','NO_CURSO']]
cursos_indigena['NO_CURSO'].value_counts()
print("\n\nCursos que possui Indígenas\n",cursos_indigena['NO_CURSO'].value_counts())
      
# Quais cursos com maior número de Indígenas formados, matricula trancada ou transferida

cursos_indigena_formado = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_COR_RACA == '5' == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
cursos_indigena_formado['NO_CURSO'].value_counts()
print("\n\nCurso com Indígenas que concluiram o ensino superior\n",cursos_indigena_formado['NO_CURSO'].value_counts()) 

cursos_indigena_trancada = aluno_curso[(aluno_curso.TP_SITUACAO == '3') & (aluno_curso.TP_COR_RACA == '5')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
cursos_indigena_trancada['NO_CURSO'].value_counts()
print("\n\nCurso com Indígenas com matrículas trancadas\n",cursos_indigena_trancada['NO_CURSO'].value_counts()) 

cursos_indigena_transferido = aluno_curso[(aluno_curso.TP_SITUACAO == '5') & (aluno_curso.TP_COR_RACA == '5')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
cursos_indigena_transferido['NO_CURSO'].value_counts()
print("\n\nCurso com Indígenas com matriculas transferidas\n",cursos_indigena_transferido['NO_CURSO'].value_counts())
# Out:
# Alunos Indígenas que concluiram o Ensino Superior: 9
#
#
# Cursos que possui Indígenas
#  CIÊNCIAS CONTÁBEIS                                       8
# ADMINISTRAÇÃO                                            7
# HISTÓRIA                                                 5
# EDUCAÇÃO FÍSICA                                          5
# ENGENHARIA MECÂNICA                                      4
# LOGÍSTICA                                                4
# ENGENHARIA CIVIL                                         4
# GESTÃO DE RECURSOS HUMANOS                               4
# DIREITO                                                  4
# MEDICINA                                                 4
# BIOMEDICINA                                              3
# REDES DE COMPUTADORES                                    3
# ENGENHARIA DE PRODUÇÃO                                   3
# CIÊNCIAS BIOLÓGICAS                                      3
# FARMÁCIA                                                 3
# GESTÃO PÚBLICA                                           3
# SERVIÇO SOCIAL                                           3
# ENGENHARIA DE CONTROLE E AUTOMAÇÃO                       2
# ENGENHARIA ELÉTRICA                                      2
# GESTÃO FINANCEIRA                                        2
# QUÍMICA                                                  2
# ENGENHARIA FLORESTAL                                     2
# LETRAS - INGLÊS                                          2
# PEDAGOGIA                                                2
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS                    2
# ENGENHARIA AMBIENTAL                                     2
# PSICOLOGIA                                               2
# LETRAS - LÍNGUA PORTUGUESA                               2
# MARKETING                                                2
# ENFERMAGEM                                               2
#                                                         ..
# FONOAUDIOLOGIA                                           1
# MÚSICA - FLAUTA DOCE                                     1
# GESTÃO AMBIENTAL                                         1
# CIÊNCIAS: BIOLOGIA, FÍSICA E QUÍMICA                     1
# CIÊNCIAS EXATAS - QUÍMICA                                1
# MÚSICA - VIOLA                                           1
# GESTÃO HOSPITALAR                                        1
# SEGURANÇA DA INFORMAÇÃO                                  1
# AGRONOMIA                                                1
# ENGENHARIA ELÉTRICA - ÊNFASE EM ELETRÔNICA E SISTEMAS    1
# LETRAS - ALEMÃO                                          1
# FÍSICA                                                   1
# TEATRO                                                   1
# GASTRONOMIA                                              1
# FILOSOFIA                                                1
# OBSTETRÍCIA                                              1
# ADMINISTRAÇÃO PÚBLICA                                    1
# CIÊNCIA E TECNOLOGIA DE ALIMENTOS                        1
# TEOLOGIA                                                 1
# FISIOTERAPIA                                             1
# JOGOS DIGITAIS                                           1
# ENGENHARIA DE COMPUTAÇÃO                                 1
# ENGENHARIA MECÂNICA AERONÁUTICA                          1
# NUTRIÇÃO                                                 1
# GESTÃO COMERCIAL                                         1
# SISTEMAS DE TELECOMUNICAÇÕES                             1
# LETRAS - POLONÊS                                         1
# ENGENHARIA DE RECURSOS HÍDRICOS E DO MEIO AMBIENTE       1
# FABRICAÇÃO MECÂNICA                                      1
# PROCESSOS GERENCIAIS                                     1
# Name: NO_CURSO, Length: 68, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-763ebc46b85f> in <module>
#      28 # Quais cursos com maior número de Indígenas formados, matricula trancada ou transferida
#      29
# ---> 30 cursos_indigena_formado = aluno_curso[(aluno_curso.TP_SITUACAO == '6') & (aluno_curso.TP_COR_RACA == '5' == '1')] [['CO_ALUNO_CURSO','NO_CURSO', 'TP_COR_RACA', 'TP_SITUACAO']]
#      31 cursos_indigena_formado['NO_CURSO'].value_counts()
#      32 print("\n\nCurso com Indígenas que concluiram o ensino superior\n",cursos_indigena_formado['NO_CURSO'].value_counts())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
